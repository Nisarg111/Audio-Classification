# %%
import librosa
import pandas as pd
import os
import numpy as np
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam
from sklearn import metrics

# %%
audio_dataset_path='UrbanSound8K/audio/'
metadata=pd.read_csv('UrbanSound8K/metadata/UrbanSound8K.csv')
metadata.head()
# Out:
#       slice_file_name    fsID  start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032    0.0   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263   58.5  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263   60.5  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263   63.0  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263   68.5  72.500000         1     5        2
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing

# %%
def features_extractor(file):
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    
    return mfccs_scaled_features

# %%
extracted_features=[]
for index_num,row in tqdm(metadata.iterrows()):
    file_name = os.path.join(os.path.abspath(audio_dataset_path),'fold'+str(row["fold"])+'/',str(row["slice_file_name"]))
    final_class_labels=row["class"]
    data=features_extractor(file_name)
    extracted_features.append([data,final_class_labels])
# Out:
# 3555it [05:03, 14.54it/s]C:\Users\This Pc\.conda\envs\tensorflow_env\lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1323
#   warnings.warn(
# 8325it [11:30, 13.28it/s]C:\Users\This Pc\.conda\envs\tensorflow_env\lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1103
#   warnings.warn(
# 8328it [11:30, 16.48it/s]C:\Users\This Pc\.conda\envs\tensorflow_env\lib\site-packages\librosa\core\spectrum.py:257: UserWarning: n_fft=2048 is too large for input signal of length=1523
#   warnings.warn(
# 8732it [12:05, 12.04it/s]

# %%
extracted_features_df=pd.DataFrame(extracted_features,columns=['feature','class'])
extracted_features_df.head()
# Out:
#                                              feature             class
# 0  [-217.35526, 70.22338, -130.38527, -53.282898,...          dog_bark
# 1  [-424.09818, 109.34077, -52.919525, 60.86475, ...  children_playing
# 2  [-458.79114, 121.38419, -46.520657, 52.00812, ...  children_playing
# 3  [-413.89984, 101.66373, -35.42945, 53.036354, ...  children_playing
# 4  [-446.60352, 113.68541, -52.402206, 60.302044,...  children_playing

# %%
X=np.array(extracted_features_df['feature'].tolist())
y=np.array(extracted_features_df['class'].tolist())

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
y=to_categorical(labelencoder.fit_transform(y))

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
num_labels=y.shape[1]

# %%
model=Sequential()
model.add(Dense(100,input_shape=(40,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(200))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime 

num_epochs = 100
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath='saved_models/audio_classification.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()
model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)
duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/100
# 201/219 [==========================>...] - ETA: 0s - loss: 10.6322 - accuracy: 0.1177
# Epoch 1: val_loss improved from inf to 2.28875, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 4s 14ms/step - loss: 10.0236 - accuracy: 0.1188 - val_loss: 2.2887 - val_accuracy: 0.1185
# Epoch 2/100
# 201/219 [==========================>...] - ETA: 0s - loss: 2.5748 - accuracy: 0.1267
# Epoch 2: val_loss improved from 2.28875 to 2.28008, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 2.5576 - accuracy: 0.1274 - val_loss: 2.2801 - val_accuracy: 0.1151
# Epoch 3/100
# 201/219 [==========================>...] - ETA: 0s - loss: 2.3329 - accuracy: 0.1384
# Epoch 3: val_loss improved from 2.28008 to 2.26686, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 2.3264 - accuracy: 0.1404 - val_loss: 2.2669 - val_accuracy: 0.1437
# Epoch 4/100
# 216/219 [============================>.] - ETA: 0s - loss: 2.2516 - accuracy: 0.1725
# Epoch 4: val_loss improved from 2.26686 to 2.14270, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 2.2522 - accuracy: 0.1724 - val_loss: 2.1427 - val_accuracy: 0.2244
# Epoch 5/100
# 196/219 [=========================>....] - ETA: 0s - loss: 2.1906 - accuracy: 0.1993
# Epoch 5: val_loss improved from 2.14270 to 2.06053, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 2.1908 - accuracy: 0.1993 - val_loss: 2.0605 - val_accuracy: 0.2776
# Epoch 6/100
# 197/219 [=========================>....] - ETA: 0s - loss: 2.1379 - accuracy: 0.2138
# Epoch 6: val_loss improved from 2.06053 to 1.96863, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 2.1256 - accuracy: 0.2179 - val_loss: 1.9686 - val_accuracy: 0.2879
# Epoch 7/100
# 203/219 [==========================>...] - ETA: 0s - loss: 2.1068 - accuracy: 0.2255
# Epoch 7: val_loss improved from 1.96863 to 1.92697, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 2.1017 - accuracy: 0.2265 - val_loss: 1.9270 - val_accuracy: 0.3228
# Epoch 8/100
# 202/219 [==========================>...] - ETA: 0s - loss: 2.0328 - accuracy: 0.2460
# Epoch 8: val_loss improved from 1.92697 to 1.86676, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 2.0275 - accuracy: 0.2484 - val_loss: 1.8668 - val_accuracy: 0.3618
# Epoch 9/100
# 211/219 [===========================>..] - ETA: 0s - loss: 1.9832 - accuracy: 0.2616
# Epoch 9: val_loss improved from 1.86676 to 1.79358, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.9799 - accuracy: 0.2640 - val_loss: 1.7936 - val_accuracy: 0.3686
# Epoch 10/100
# 210/219 [===========================>..] - ETA: 0s - loss: 1.9229 - accuracy: 0.2996
# Epoch 10: val_loss improved from 1.79358 to 1.74124, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.9209 - accuracy: 0.2985 - val_loss: 1.7412 - val_accuracy: 0.4047
# Epoch 11/100
# 217/219 [============================>.] - ETA: 0s - loss: 1.8735 - accuracy: 0.3188
# Epoch 11: val_loss improved from 1.74124 to 1.69766, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.8719 - accuracy: 0.3193 - val_loss: 1.6977 - val_accuracy: 0.4121
# Epoch 12/100
# 203/219 [==========================>...] - ETA: 0s - loss: 1.8288 - accuracy: 0.3307
# Epoch 12: val_loss improved from 1.69766 to 1.63496, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.8271 - accuracy: 0.3320 - val_loss: 1.6350 - val_accuracy: 0.4459
# Epoch 13/100
# 211/219 [===========================>..] - ETA: 0s - loss: 1.7763 - accuracy: 0.3503
# Epoch 13: val_loss improved from 1.63496 to 1.58993, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.7766 - accuracy: 0.3513 - val_loss: 1.5899 - val_accuracy: 0.4671
# Epoch 14/100
# 205/219 [===========================>..] - ETA: 0s - loss: 1.7484 - accuracy: 0.3634
# Epoch 14: val_loss improved from 1.58993 to 1.52781, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.7446 - accuracy: 0.3655 - val_loss: 1.5278 - val_accuracy: 0.4757
# Epoch 15/100
# 210/219 [===========================>..] - ETA: 0s - loss: 1.6960 - accuracy: 0.3970
# Epoch 15: val_loss improved from 1.52781 to 1.49161, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.6971 - accuracy: 0.3971 - val_loss: 1.4916 - val_accuracy: 0.4991
# Epoch 16/100
# 208/219 [===========================>..] - ETA: 0s - loss: 1.6684 - accuracy: 0.4088
# Epoch 16: val_loss improved from 1.49161 to 1.49002, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.6691 - accuracy: 0.4079 - val_loss: 1.4900 - val_accuracy: 0.5112
# Epoch 17/100
# 214/219 [============================>.] - ETA: 0s - loss: 1.6181 - accuracy: 0.4246
# Epoch 17: val_loss improved from 1.49002 to 1.42915, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.6192 - accuracy: 0.4245 - val_loss: 1.4291 - val_accuracy: 0.5249
# Epoch 18/100
# 215/219 [============================>.] - ETA: 0s - loss: 1.5975 - accuracy: 0.4321
# Epoch 18: val_loss did not improve from 1.42915
# 219/219 [==============================] - 1s 3ms/step - loss: 1.5979 - accuracy: 0.4311 - val_loss: 1.4426 - val_accuracy: 0.5123
# Epoch 19/100
# 207/219 [===========================>..] - ETA: 0s - loss: 1.5723 - accuracy: 0.4494
# Epoch 19: val_loss improved from 1.42915 to 1.41105, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.5729 - accuracy: 0.4472 - val_loss: 1.4110 - val_accuracy: 0.5409
# Epoch 20/100
# 211/219 [===========================>..] - ETA: 0s - loss: 1.5403 - accuracy: 0.4560
# Epoch 20: val_loss improved from 1.41105 to 1.37335, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.5416 - accuracy: 0.4567 - val_loss: 1.3733 - val_accuracy: 0.5638
# Epoch 21/100
# 203/219 [==========================>...] - ETA: 0s - loss: 1.5166 - accuracy: 0.4580
# Epoch 21: val_loss improved from 1.37335 to 1.35304, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.5181 - accuracy: 0.4581 - val_loss: 1.3530 - val_accuracy: 0.5512
# Epoch 22/100
# 214/219 [============================>.] - ETA: 0s - loss: 1.5065 - accuracy: 0.4711
# Epoch 22: val_loss improved from 1.35304 to 1.29444, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.5057 - accuracy: 0.4712 - val_loss: 1.2944 - val_accuracy: 0.5884
# Epoch 23/100
# 202/219 [==========================>...] - ETA: 0s - loss: 1.4903 - accuracy: 0.4800
# Epoch 23: val_loss did not improve from 1.29444
# 219/219 [==============================] - 1s 4ms/step - loss: 1.4875 - accuracy: 0.4813 - val_loss: 1.3226 - val_accuracy: 0.5541
# Epoch 24/100
# 209/219 [===========================>..] - ETA: 0s - loss: 1.4387 - accuracy: 0.4958
# Epoch 24: val_loss improved from 1.29444 to 1.27428, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.4389 - accuracy: 0.4952 - val_loss: 1.2743 - val_accuracy: 0.5535
# Epoch 25/100
# 203/219 [==========================>...] - ETA: 0s - loss: 1.4168 - accuracy: 0.5146
# Epoch 25: val_loss improved from 1.27428 to 1.23625, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.4166 - accuracy: 0.5124 - val_loss: 1.2363 - val_accuracy: 0.5902
# Epoch 26/100
# 217/219 [============================>.] - ETA: 0s - loss: 1.4002 - accuracy: 0.5121
# Epoch 26: val_loss improved from 1.23625 to 1.21240, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.3994 - accuracy: 0.5124 - val_loss: 1.2124 - val_accuracy: 0.6010
# Epoch 27/100
# 204/219 [==========================>...] - ETA: 0s - loss: 1.4007 - accuracy: 0.5175
# Epoch 27: val_loss improved from 1.21240 to 1.20044, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.3920 - accuracy: 0.5225 - val_loss: 1.2004 - val_accuracy: 0.6125
# Epoch 28/100
# 219/219 [==============================] - ETA: 0s - loss: 1.3726 - accuracy: 0.5151
# Epoch 28: val_loss did not improve from 1.20044
# 219/219 [==============================] - 1s 4ms/step - loss: 1.3726 - accuracy: 0.5151 - val_loss: 1.2133 - val_accuracy: 0.6010
# Epoch 29/100
# 215/219 [============================>.] - ETA: 0s - loss: 1.3508 - accuracy: 0.5243
# Epoch 29: val_loss improved from 1.20044 to 1.16980, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.3489 - accuracy: 0.5254 - val_loss: 1.1698 - val_accuracy: 0.6251
# Epoch 30/100
# 213/219 [============================>.] - ETA: 0s - loss: 1.3423 - accuracy: 0.5311
# Epoch 30: val_loss improved from 1.16980 to 1.13174, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.3414 - accuracy: 0.5326 - val_loss: 1.1317 - val_accuracy: 0.6440
# Epoch 31/100
# 217/219 [============================>.] - ETA: 0s - loss: 1.3313 - accuracy: 0.5438
# Epoch 31: val_loss did not improve from 1.13174
# 219/219 [==============================] - 1s 3ms/step - loss: 1.3318 - accuracy: 0.5436 - val_loss: 1.1838 - val_accuracy: 0.6279
# Epoch 32/100
# 201/219 [==========================>...] - ETA: 0s - loss: 1.3226 - accuracy: 0.5477
# Epoch 32: val_loss did not improve from 1.13174
# 219/219 [==============================] - 1s 4ms/step - loss: 1.3172 - accuracy: 0.5495 - val_loss: 1.1458 - val_accuracy: 0.6302
# Epoch 33/100
# 198/219 [==========================>...] - ETA: 0s - loss: 1.2867 - accuracy: 0.5538
# Epoch 33: val_loss improved from 1.13174 to 1.11748, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.2885 - accuracy: 0.5545 - val_loss: 1.1175 - val_accuracy: 0.6371
# Epoch 34/100
# 202/219 [==========================>...] - ETA: 0s - loss: 1.2855 - accuracy: 0.5563
# Epoch 34: val_loss improved from 1.11748 to 1.10791, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.2824 - accuracy: 0.5573 - val_loss: 1.1079 - val_accuracy: 0.6468
# Epoch 35/100
# 211/219 [===========================>..] - ETA: 0s - loss: 1.2542 - accuracy: 0.5714
# Epoch 35: val_loss improved from 1.10791 to 1.09633, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.2527 - accuracy: 0.5708 - val_loss: 1.0963 - val_accuracy: 0.6491
# Epoch 36/100
# 206/219 [===========================>..] - ETA: 0s - loss: 1.2470 - accuracy: 0.5687
# Epoch 36: val_loss improved from 1.09633 to 1.06998, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.2496 - accuracy: 0.5666 - val_loss: 1.0700 - val_accuracy: 0.6520
# Epoch 37/100
# 204/219 [==========================>...] - ETA: 0s - loss: 1.2316 - accuracy: 0.5816
# Epoch 37: val_loss improved from 1.06998 to 1.03758, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.2262 - accuracy: 0.5828 - val_loss: 1.0376 - val_accuracy: 0.6714
# Epoch 38/100
# 206/219 [===========================>..] - ETA: 0s - loss: 1.2205 - accuracy: 0.5815
# Epoch 38: val_loss did not improve from 1.03758
# 219/219 [==============================] - 1s 4ms/step - loss: 1.2208 - accuracy: 0.5827 - val_loss: 1.0554 - val_accuracy: 0.6646
# Epoch 39/100
# 204/219 [==========================>...] - ETA: 0s - loss: 1.2271 - accuracy: 0.5859
# Epoch 39: val_loss improved from 1.03758 to 1.02163, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.2316 - accuracy: 0.5840 - val_loss: 1.0216 - val_accuracy: 0.6800
# Epoch 40/100
# 215/219 [============================>.] - ETA: 0s - loss: 1.2134 - accuracy: 0.5855
# Epoch 40: val_loss did not improve from 1.02163
# 219/219 [==============================] - 1s 4ms/step - loss: 1.2149 - accuracy: 0.5851 - val_loss: 1.0357 - val_accuracy: 0.6674
# Epoch 41/100
# 203/219 [==========================>...] - ETA: 0s - loss: 1.1851 - accuracy: 0.5961
# Epoch 41: val_loss improved from 1.02163 to 1.01704, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.1827 - accuracy: 0.5971 - val_loss: 1.0170 - val_accuracy: 0.6783
# Epoch 42/100
# 212/219 [============================>.] - ETA: 0s - loss: 1.1906 - accuracy: 0.5951
# Epoch 42: val_loss did not improve from 1.01704
# 219/219 [==============================] - 1s 4ms/step - loss: 1.1891 - accuracy: 0.5954 - val_loss: 1.0215 - val_accuracy: 0.6880
# Epoch 43/100
# 212/219 [============================>.] - ETA: 0s - loss: 1.2056 - accuracy: 0.5917
# Epoch 43: val_loss improved from 1.01704 to 1.00192, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.2073 - accuracy: 0.5928 - val_loss: 1.0019 - val_accuracy: 0.6857
# Epoch 44/100
# 206/219 [===========================>..] - ETA: 0s - loss: 1.1797 - accuracy: 0.5966
# Epoch 44: val_loss improved from 1.00192 to 0.97719, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.1806 - accuracy: 0.5958 - val_loss: 0.9772 - val_accuracy: 0.6880
# Epoch 45/100
# 205/219 [===========================>..] - ETA: 0s - loss: 1.1627 - accuracy: 0.6082
# Epoch 45: val_loss did not improve from 0.97719
# 219/219 [==============================] - 1s 4ms/step - loss: 1.1617 - accuracy: 0.6080 - val_loss: 0.9783 - val_accuracy: 0.6989
# Epoch 46/100
# 201/219 [==========================>...] - ETA: 0s - loss: 1.1552 - accuracy: 0.6074
# Epoch 46: val_loss improved from 0.97719 to 0.97412, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.1529 - accuracy: 0.6077 - val_loss: 0.9741 - val_accuracy: 0.6812
# Epoch 47/100
# 218/219 [============================>.] - ETA: 0s - loss: 1.1490 - accuracy: 0.6104
# Epoch 47: val_loss improved from 0.97412 to 0.96781, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.1491 - accuracy: 0.6100 - val_loss: 0.9678 - val_accuracy: 0.6983
# Epoch 48/100
# 214/219 [============================>.] - ETA: 0s - loss: 1.1487 - accuracy: 0.6079
# Epoch 48: val_loss did not improve from 0.96781
# 219/219 [==============================] - 1s 3ms/step - loss: 1.1458 - accuracy: 0.6089 - val_loss: 0.9739 - val_accuracy: 0.6835
# Epoch 49/100
# 211/219 [===========================>..] - ETA: 0s - loss: 1.1337 - accuracy: 0.6146
# Epoch 49: val_loss improved from 0.96781 to 0.92810, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.1317 - accuracy: 0.6150 - val_loss: 0.9281 - val_accuracy: 0.7138
# Epoch 50/100
# 203/219 [==========================>...] - ETA: 0s - loss: 1.1134 - accuracy: 0.6165
# Epoch 50: val_loss did not improve from 0.92810
# 219/219 [==============================] - 1s 4ms/step - loss: 1.1185 - accuracy: 0.6188 - val_loss: 0.9302 - val_accuracy: 0.7041
# Epoch 51/100
# 204/219 [==========================>...] - ETA: 0s - loss: 1.0971 - accuracy: 0.6319
# Epoch 51: val_loss did not improve from 0.92810
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0941 - accuracy: 0.6321 - val_loss: 0.9363 - val_accuracy: 0.6943
# Epoch 52/100
# 207/219 [===========================>..] - ETA: 0s - loss: 1.1076 - accuracy: 0.6250
# Epoch 52: val_loss did not improve from 0.92810
# 219/219 [==============================] - 1s 4ms/step - loss: 1.1008 - accuracy: 0.6261 - val_loss: 0.9467 - val_accuracy: 0.6938
# Epoch 53/100
# 213/219 [============================>.] - ETA: 0s - loss: 1.1023 - accuracy: 0.6273
# Epoch 53: val_loss did not improve from 0.92810
# 219/219 [==============================] - 1s 5ms/step - loss: 1.1005 - accuracy: 0.6268 - val_loss: 0.9339 - val_accuracy: 0.6961
# Epoch 54/100
# 206/219 [===========================>..] - ETA: 0s - loss: 1.1046 - accuracy: 0.6215
# Epoch 54: val_loss improved from 0.92810 to 0.91114, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.1045 - accuracy: 0.6232 - val_loss: 0.9111 - val_accuracy: 0.7098
# Epoch 55/100
# 204/219 [==========================>...] - ETA: 0s - loss: 1.0853 - accuracy: 0.6320
# Epoch 55: val_loss improved from 0.91114 to 0.90584, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0917 - accuracy: 0.6315 - val_loss: 0.9058 - val_accuracy: 0.7041
# Epoch 56/100
# 212/219 [============================>.] - ETA: 0s - loss: 1.1121 - accuracy: 0.6265
# Epoch 56: val_loss improved from 0.90584 to 0.90483, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.1099 - accuracy: 0.6272 - val_loss: 0.9048 - val_accuracy: 0.7184
# Epoch 57/100
# 212/219 [============================>.] - ETA: 0s - loss: 1.0764 - accuracy: 0.6408
# Epoch 57: val_loss improved from 0.90483 to 0.90202, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0787 - accuracy: 0.6388 - val_loss: 0.9020 - val_accuracy: 0.7109
# Epoch 58/100
# 205/219 [===========================>..] - ETA: 0s - loss: 1.1021 - accuracy: 0.6363
# Epoch 58: val_loss did not improve from 0.90202
# 219/219 [==============================] - 1s 3ms/step - loss: 1.1024 - accuracy: 0.6355 - val_loss: 0.9229 - val_accuracy: 0.7115
# Epoch 59/100
# 204/219 [==========================>...] - ETA: 0s - loss: 1.0795 - accuracy: 0.6317
# Epoch 59: val_loss improved from 0.90202 to 0.89029, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0807 - accuracy: 0.6316 - val_loss: 0.8903 - val_accuracy: 0.7378
# Epoch 60/100
# 216/219 [============================>.] - ETA: 0s - loss: 1.0817 - accuracy: 0.6415
# Epoch 60: val_loss improved from 0.89029 to 0.87365, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0815 - accuracy: 0.6409 - val_loss: 0.8737 - val_accuracy: 0.7224
# Epoch 61/100
# 212/219 [============================>.] - ETA: 0s - loss: 1.0633 - accuracy: 0.6386
# Epoch 61: val_loss did not improve from 0.87365
# 219/219 [==============================] - 1s 3ms/step - loss: 1.0637 - accuracy: 0.6391 - val_loss: 0.8906 - val_accuracy: 0.7310
# Epoch 62/100
# 204/219 [==========================>...] - ETA: 0s - loss: 1.0897 - accuracy: 0.6297
# Epoch 62: val_loss did not improve from 0.87365
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0919 - accuracy: 0.6301 - val_loss: 0.9172 - val_accuracy: 0.7104
# Epoch 63/100
# 208/219 [===========================>..] - ETA: 0s - loss: 1.0718 - accuracy: 0.6340
# Epoch 63: val_loss did not improve from 0.87365
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0677 - accuracy: 0.6354 - val_loss: 0.8896 - val_accuracy: 0.7224
# Epoch 64/100
# 209/219 [===========================>..] - ETA: 0s - loss: 1.0615 - accuracy: 0.6422
# Epoch 64: val_loss improved from 0.87365 to 0.86769, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0580 - accuracy: 0.6431 - val_loss: 0.8677 - val_accuracy: 0.7327
# Epoch 65/100
# 218/219 [============================>.] - ETA: 0s - loss: 1.0397 - accuracy: 0.6469
# Epoch 65: val_loss did not improve from 0.86769
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0399 - accuracy: 0.6467 - val_loss: 0.8836 - val_accuracy: 0.7235
# Epoch 66/100
# 214/219 [============================>.] - ETA: 0s - loss: 1.0542 - accuracy: 0.6481
# Epoch 66: val_loss did not improve from 0.86769
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0551 - accuracy: 0.6481 - val_loss: 0.8684 - val_accuracy: 0.7355
# Epoch 67/100
# 211/219 [===========================>..] - ETA: 0s - loss: 1.0257 - accuracy: 0.6533
# Epoch 67: val_loss improved from 0.86769 to 0.85996, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0271 - accuracy: 0.6525 - val_loss: 0.8600 - val_accuracy: 0.7378
# Epoch 68/100
# 211/219 [===========================>..] - ETA: 0s - loss: 1.0518 - accuracy: 0.6447
# Epoch 68: val_loss did not improve from 0.85996
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0581 - accuracy: 0.6437 - val_loss: 0.8896 - val_accuracy: 0.7333
# Epoch 69/100
# 214/219 [============================>.] - ETA: 0s - loss: 1.0510 - accuracy: 0.6456
# Epoch 69: val_loss improved from 0.85996 to 0.85793, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0478 - accuracy: 0.6465 - val_loss: 0.8579 - val_accuracy: 0.7413
# Epoch 70/100
# 205/219 [===========================>..] - ETA: 0s - loss: 1.0457 - accuracy: 0.6491
# Epoch 70: val_loss did not improve from 0.85793
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0458 - accuracy: 0.6491 - val_loss: 0.8637 - val_accuracy: 0.7459
# Epoch 71/100
# 197/219 [=========================>....] - ETA: 0s - loss: 1.0318 - accuracy: 0.6510
# Epoch 71: val_loss improved from 0.85793 to 0.82462, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0263 - accuracy: 0.6554 - val_loss: 0.8246 - val_accuracy: 0.7470
# Epoch 72/100
# 206/219 [===========================>..] - ETA: 0s - loss: 1.0325 - accuracy: 0.6566
# Epoch 72: val_loss did not improve from 0.82462
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0376 - accuracy: 0.6565 - val_loss: 0.8633 - val_accuracy: 0.7241
# Epoch 73/100
# 218/219 [============================>.] - ETA: 0s - loss: 1.0240 - accuracy: 0.6570
# Epoch 73: val_loss did not improve from 0.82462
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0243 - accuracy: 0.6568 - val_loss: 0.8487 - val_accuracy: 0.7464
# Epoch 74/100
# 199/219 [==========================>...] - ETA: 0s - loss: 1.0301 - accuracy: 0.6578
# Epoch 74: val_loss did not improve from 0.82462
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0429 - accuracy: 0.6547 - val_loss: 0.8644 - val_accuracy: 0.7333
# Epoch 75/100
# 209/219 [===========================>..] - ETA: 0s - loss: 1.0127 - accuracy: 0.6618
# Epoch 75: val_loss did not improve from 0.82462
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0161 - accuracy: 0.6608 - val_loss: 0.8416 - val_accuracy: 0.7373
# Epoch 76/100
# 208/219 [===========================>..] - ETA: 0s - loss: 1.0098 - accuracy: 0.6575
# Epoch 76: val_loss improved from 0.82462 to 0.82263, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0077 - accuracy: 0.6594 - val_loss: 0.8226 - val_accuracy: 0.7441
# Epoch 77/100
# 205/219 [===========================>..] - ETA: 0s - loss: 1.0182 - accuracy: 0.6582
# Epoch 77: val_loss did not improve from 0.82263
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0254 - accuracy: 0.6548 - val_loss: 0.8957 - val_accuracy: 0.7172
# Epoch 78/100
# 205/219 [===========================>..] - ETA: 0s - loss: 1.0053 - accuracy: 0.6610
# Epoch 78: val_loss did not improve from 0.82263
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0061 - accuracy: 0.6598 - val_loss: 0.8611 - val_accuracy: 0.7275
# Epoch 79/100
# 211/219 [===========================>..] - ETA: 0s - loss: 1.0379 - accuracy: 0.6545
# Epoch 79: val_loss did not improve from 0.82263
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0361 - accuracy: 0.6543 - val_loss: 0.8571 - val_accuracy: 0.7264
# Epoch 80/100
# 206/219 [===========================>..] - ETA: 0s - loss: 0.9875 - accuracy: 0.6728
# Epoch 80: val_loss did not improve from 0.82263
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9923 - accuracy: 0.6726 - val_loss: 0.8240 - val_accuracy: 0.7459
# Epoch 81/100
# 212/219 [============================>.] - ETA: 0s - loss: 1.0147 - accuracy: 0.6607
# Epoch 81: val_loss improved from 0.82263 to 0.81469, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0143 - accuracy: 0.6617 - val_loss: 0.8147 - val_accuracy: 0.7544
# Epoch 82/100
# 207/219 [===========================>..] - ETA: 0s - loss: 1.0262 - accuracy: 0.6617
# Epoch 82: val_loss improved from 0.81469 to 0.80415, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 5ms/step - loss: 1.0209 - accuracy: 0.6630 - val_loss: 0.8041 - val_accuracy: 0.7527
# Epoch 83/100
# 206/219 [===========================>..] - ETA: 0s - loss: 0.9866 - accuracy: 0.6714
# Epoch 83: val_loss did not improve from 0.80415
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9878 - accuracy: 0.6712 - val_loss: 0.8225 - val_accuracy: 0.7453
# Epoch 84/100
# 211/219 [===========================>..] - ETA: 0s - loss: 1.0063 - accuracy: 0.6626
# Epoch 84: val_loss did not improve from 0.80415
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0081 - accuracy: 0.6626 - val_loss: 0.8200 - val_accuracy: 0.7476
# Epoch 85/100
# 216/219 [============================>.] - ETA: 0s - loss: 0.9875 - accuracy: 0.6717
# Epoch 85: val_loss did not improve from 0.80415
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9860 - accuracy: 0.6720 - val_loss: 0.8273 - val_accuracy: 0.7418
# Epoch 86/100
# 207/219 [===========================>..] - ETA: 0s - loss: 1.0042 - accuracy: 0.6618
# Epoch 86: val_loss did not improve from 0.80415
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0035 - accuracy: 0.6624 - val_loss: 0.8134 - val_accuracy: 0.7556
# Epoch 87/100
# 200/219 [==========================>...] - ETA: 0s - loss: 0.9961 - accuracy: 0.6625
# Epoch 87: val_loss did not improve from 0.80415
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9991 - accuracy: 0.6613 - val_loss: 0.8065 - val_accuracy: 0.7636
# Epoch 88/100
# 208/219 [===========================>..] - ETA: 0s - loss: 1.0035 - accuracy: 0.6657
# Epoch 88: val_loss did not improve from 0.80415
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0031 - accuracy: 0.6654 - val_loss: 0.8292 - val_accuracy: 0.7401
# Epoch 89/100
# 202/219 [==========================>...] - ETA: 0s - loss: 0.9760 - accuracy: 0.6779
# Epoch 89: val_loss did not improve from 0.80415
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9759 - accuracy: 0.6780 - val_loss: 0.8295 - val_accuracy: 0.7533
# Epoch 90/100
# 208/219 [===========================>..] - ETA: 0s - loss: 1.0294 - accuracy: 0.6623
# Epoch 90: val_loss did not improve from 0.80415
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0304 - accuracy: 0.6603 - val_loss: 0.8125 - val_accuracy: 0.7590
# Epoch 91/100
# 216/219 [============================>.] - ETA: 0s - loss: 0.9655 - accuracy: 0.6808
# Epoch 91: val_loss did not improve from 0.80415
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9659 - accuracy: 0.6812 - val_loss: 0.8135 - val_accuracy: 0.7562
# Epoch 92/100
# 218/219 [============================>.] - ETA: 0s - loss: 1.0007 - accuracy: 0.6693
# Epoch 92: val_loss improved from 0.80415 to 0.80281, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 1.0007 - accuracy: 0.6693 - val_loss: 0.8028 - val_accuracy: 0.7619
# Epoch 93/100
# 202/219 [==========================>...] - ETA: 0s - loss: 0.9949 - accuracy: 0.6699
# Epoch 93: val_loss did not improve from 0.80281
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9928 - accuracy: 0.6709 - val_loss: 0.8424 - val_accuracy: 0.7464
# Epoch 94/100
# 218/219 [============================>.] - ETA: 0s - loss: 0.9759 - accuracy: 0.6729
# Epoch 94: val_loss improved from 0.80281 to 0.78948, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9758 - accuracy: 0.6727 - val_loss: 0.7895 - val_accuracy: 0.7579
# Epoch 95/100
# 218/219 [============================>.] - ETA: 0s - loss: 0.9721 - accuracy: 0.6752
# Epoch 95: val_loss did not improve from 0.78948
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9716 - accuracy: 0.6753 - val_loss: 0.7896 - val_accuracy: 0.7619
# Epoch 96/100
# 212/219 [============================>.] - ETA: 0s - loss: 0.9620 - accuracy: 0.6840
# Epoch 96: val_loss did not improve from 0.78948
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9641 - accuracy: 0.6832 - val_loss: 0.7904 - val_accuracy: 0.7487
# Epoch 97/100
# 204/219 [==========================>...] - ETA: 0s - loss: 0.9740 - accuracy: 0.6697
# Epoch 97: val_loss did not improve from 0.78948
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9771 - accuracy: 0.6693 - val_loss: 0.8228 - val_accuracy: 0.7430
# Epoch 98/100
# 211/219 [===========================>..] - ETA: 0s - loss: 0.9771 - accuracy: 0.6730
# Epoch 98: val_loss improved from 0.78948 to 0.78585, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9789 - accuracy: 0.6719 - val_loss: 0.7858 - val_accuracy: 0.7602
# Epoch 99/100
# 206/219 [===========================>..] - ETA: 0s - loss: 0.9969 - accuracy: 0.6676
# Epoch 99: val_loss improved from 0.78585 to 0.76846, saving model to saved_models\audio_classification.hdf5
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9889 - accuracy: 0.6687 - val_loss: 0.7685 - val_accuracy: 0.7653
# Epoch 100/100
# 217/219 [============================>.] - ETA: 0s - loss: 0.9888 - accuracy: 0.6717
# Epoch 100: val_loss did not improve from 0.76846
# 219/219 [==============================] - 1s 4ms/step - loss: 0.9897 - accuracy: 0.6714 - val_loss: 0.7702 - val_accuracy: 0.7728
# Training completed in time:  0:01:32.150889

# %%
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.7727532982826233

# %%
filename="Engine.wav"
audio, sample_rate = librosa.load(filename, res_type='kaiser_fast') 
mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
mfccs_scaled_features=mfccs_scaled_features.reshape(1,-1)
predict=model.predict(mfccs_scaled_features)
predicted_label = np.argmax(predict,axis=1)
predicted_class = labelencoder.inverse_transform(predicted_label) 
predicted_class
# Out:
# 1/1 [==============================] - 0s 24ms/step
# array(['engine_idling'], dtype='<U16')
